# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [-6.61391222  3.52448633 31.5837217   0.14160042  0.07384676  0.        ]
# [-3.66030914  2.56643865  6.45514195]
# [ 0.07753736 -0.03535911  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 1000
target_pos = np.array([0., 0., 0.])  # teach quadcopter to land (x=0, y=0, z=0)
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode = 1000, score =  -4.942 (best =  -2.724), noise_scale = 3.2555

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
## TODO: Train your agent here.
from agents.agent import My_Agent
from task import Task1

# reduce learning rate to from 0.3 to 0.001

num_episodes = 1000
target_pos = np.array([0., 0., 0.])  # teach Quadcopter to land (x=0, y=0, z=0)
task = Task1(target_pos=target_pos)
agent = My_Agent(task)

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode = 1000, score =   2.975 (best =   2.980), noise_scale = 3.255

# %%
## TODO: Train your agent here.
from agents.agent import My_Agent
from task import Task2

# increase repeat action from 3x to 10x

num_episodes = 1000
target_pos = np.array([0., 0., 0.])  # teach Quadcopter to land (x=0, y=0, z=0)
task = Task2(target_pos=target_pos)
agent = My_Agent(task)

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode = 1000, score =   9.939 (best =   9.941), noise_scale = 3.255

# %%
## TODO: Train your agent here.
from agents.agent import My_Agent
from task import Task3

# give big reward if position == goal
    
task3_runtime = 5.                                     # time limit of the episode
task3_init_pose = np.array([0., 0., 5., 0., 0., 0.]) # initial pose
task3_init_velocities = np.array([5., 5., 5.])         # initial velocities
task3_init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
task3_file_output = 'task3_data.txt'                         # file name for saved results

num_episodes = 1000
task3_target_pos = np.array([0., 0., 0.])  # teach Quadcopter to land (x=0, y=0, z=0)
task = Task3(task3_init_pose, task3_init_velocities, task3_init_angle_velocities, task3_runtime, target_pos=task3_target_pos)
agent = My_Agent(task)
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4', 'reward']
task3_results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(task3_file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    for i_episode in range(1, num_episodes+1):
        state = agent.reset_episode() # start a new episode
        while True:
            action = agent.act(state) 
            next_state, reward, done = task.step(action)
            agent.step(reward, done)
            state = next_state
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds) + [reward]
            for ii in range(len(labels)):
                task3_results[labels[ii]].append(to_write[ii])
            writer.writerow(to_write)
            if done:
                print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                    i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
                break
        sys.stdout.flush()
# Out:
# Episode = 1000, score =  34.394 (best =  79.923), noise_scale = 3.255

# %%
task3_result = pd.read_csv("task3_data.txt", header=0)
print(task3_result['z'].describe())
task3_result.loc[task3_result['z'] == 0.0]
# plt.plot(landing, label='z')
# plt.legend()
# _ = plt.ylim()
# Out:
# count    8823.000000
# mean        4.139874
# std         2.307830
# min         0.000000
# 25%         2.297366
# 50%         5.175958
# 75%         6.046664
# max         8.514043
# Name: z, dtype: float64
#       time          x          y    z       phi     theta  psi  x_velocity  \
# 8      1.8   8.353662   8.414107  0.0  4.474938  3.742308  0.0    4.908253
# 17     1.8   8.434472   8.368167  0.0  4.604643  3.734630  0.0    5.123176
# 26     1.8   8.244449   8.559623  0.0  4.590330  4.133758  0.0    4.375069
# 35     1.8   8.323456   8.579855  0.0  4.697527  3.860152  0.0    4.675921
# 44     1.8   8.376434   8.465225  0.0  4.256288  3.748900  0.0    4.983680
# 53     1.8   8.253592   8.488548  0.0  4.221511  4.138467  0.0    4.493600
# 62     1.8   8.341725   8.466073  0.0  4.259279  4.043067  0.0    4.815973
# 71     1.8   8.175301   8.594970  0.0  4.439056  4.508074  0.0    4.109322
# 80     1.8   8.212417   8.598455  0.0  3.707301  4.368964  0.0    4.333988
# 89     1.8   8.046182   8.730352  0.0  1.654202  5.846913  0.0    4.021830
# 98     1.8   8.170493   8.842840  0.0  0.018229  0.691347  0.0    4.491759
# 107    1.8   8.795145   8.887199  0.0  5.782677  6.243676  0.0    5.061377
# 116    1.8   8.075389   8.413552  0.0  6.067988  1.332561  0.0    4.168418
# 125    1.8   7.313553   8.845871  0.0  0.875274  4.506438  0.0    3.284318
# 134    1.8   8.353638   8.302795  0.0  1.048654  4.165655  0.0    4.251158
# 143    1.8   7.487377   8.901298  0.0  5.270499  1.904699  0.0    3.296178
# 152    1.8   7.730120   9.355582  0.0  3.203337  4.557566  0.0    3.742248
# 161    1.8   8.489371   8.844164  0.0  2.367515  1.277375  0.0    5.256030
# 170    1.8   7.983463   8.938462  0.0  4.343169  3.956543  0.0    4.629011
# 179    1.8   7.692094   8.687709  0.0  5.759652  1.290452  0.0    3.379275
# 188    1.8   8.189568   8.360502  0.0  0.349888  5.830079  0.0    4.135132
# 197    1.8   6.878179   8.859380  0.0  0.911703  5.991365  0.0    2.201034
# 206    1.8   7.874156   8.793733  0.0  1.843829  2.337468  0.0    4.132425
# 215    1.8   6.855505   9.132915  0.0  6.140578  2.871358  0.0    2.716613
# 224    1.8   7.898962   8.682145  0.0  1.852254  2.504156  0.0    3.684352
# 233    1.8   8.086500   8.697108  0.0  3.125158  1.477689  0.0    3.659080
# 242    1.8   9.742035   8.828435  0.0  4.128625  3.054596  0.0    6.404897
# 251    1.8   7.839441   8.905322  0.0  3.768075  5.071900  0.0    3.414719
# 260    1.8   9.515626   9.417201  0.0  2.558751  2.884634  0.0    5.651074
# 269    1.8   7.450771   8.834345  0.0  5.701528  5.981873  0.0    3.363981
# ...    ...        ...        ...  ...       ...       ...  ...         ...
# 8569   1.4   4.110730   6.829335  0.0  2.810361  4.062341  0.0    3.574830
# 8576   1.4   5.608153   9.501077  0.0  3.101931  1.930273  0.0    4.103214
# 8583   1.4   4.296319   5.350026  0.0  4.347569  5.221528  0.0    3.517213
# 8591   1.6   3.266342  11.774632  0.0  6.058373  4.996977  0.0    1.039587
# 8600   1.8  -7.970802   5.658827  0.0  0.868403  4.761501  0.0  -11.884446
# 8609   1.8   7.247988   6.046982  0.0  3.706702  3.848012  0.0    7.575089
# 8618   1.8  -2.354909   6.355064  0.0  2.907651  3.760093  0.0   -4.433224
# 8625   1.4   2.103599   7.548705  0.0  4.716838  4.263036  0.0    1.381715
# 8633   1.6   0.790341   8.259147  0.0  4.927511  3.974042  0.0   -3.941041
# 8644   2.2   8.972345  21.644504  0.0  4.871367  6.004254  0.0    4.928141
# 8651   1.4   5.785516   7.153221  0.0  1.936615  2.009075  0.0    5.332709
# 8660   1.8   0.181600  14.932250  0.0  2.567597  4.451721  0.0   -2.658688
# 8667   1.4  -1.951789   6.562010  0.0  2.944977  5.218767  0.0   -6.846993
# 8676   1.8   8.731617   5.050111  0.0  5.630182  2.875994  0.0    7.468332
# 8687   2.2   3.395445   6.379427  0.0  2.574263  5.943957  0.0   -1.372803
# 8699   2.4   7.759935  19.605020  0.0  1.545822  3.032948  0.0    6.663956
# 8708   1.8   3.445973  15.053799  0.0  5.095122  3.756397  0.0    2.737449
# 8716   1.6   3.885995   3.007458  0.0  5.749610  4.714495  0.0    3.671806
# 8723   1.4   2.579450   6.516288  0.0  1.989225  3.956295  0.0   -0.698158
# 8734   2.2  21.662473  10.001008  0.0  1.696583  1.616167  0.0   15.295584
# 8745   2.2   3.422631  12.691225  0.0  4.714597  0.542123  0.0   -1.536906
# 8752   1.4   2.763190   8.519409  0.0  0.744681  3.756884  0.0    3.331991
# 8766   2.8   2.215241  20.052566  0.0  0.740423  2.132727  0.0    2.039239
# 8774   1.6   4.819914  16.377926  0.0  0.377827  3.097571  0.0    9.458880
# 8782   1.6   9.572370   6.325070  0.0  3.466579  3.894787  0.0   10.246726
# 8790   1.6  -0.031731   9.086448  0.0  5.403352  0.291861  0.0   -1.747215
# 8797   1.4   4.011602   6.146449  0.0  3.891583  0.179901  0.0    1.486966
# 8807   2.0  -3.600041   8.392415  0.0  1.011678  0.352871  0.0   -8.419510
# 8814   1.4   6.047984   5.805464  0.0  1.888031  2.227218  0.0    5.732940
# 8822   1.6  -3.573729  11.508505  0.0  1.408358  4.783489  0.0   -7.547043
#
#       y_velocity  z_velocity  phi_velocity  theta_velocity  psi_velocity  \
# 8       4.750503  -12.902923      8.868532       -4.545837           0.0
# 17      4.669364  -12.825377      9.357970       -4.195659           0.0
# 26      4.849282  -13.262865      8.767001       -4.380521           0.0
# 35      4.930064  -13.339923      8.818290       -4.500235           0.0
# 44      4.785327  -12.973749      8.547183       -4.392148           0.0
# 53      4.737952  -13.112668      8.474731       -4.214190           0.0
# 62      4.742980  -13.026316      8.686888       -3.861177           0.0
# 71      4.837110  -12.657214      9.140401       -4.185815           0.0
# 80      4.876891  -12.480784      8.301283       -5.466838           0.0
# 89      4.891871  -12.993905      7.157762       -1.297484           0.0
# 98      5.316311  -13.387512      9.321676        2.839298           0.0
# 107     5.361463  -12.484466      7.525985       -5.987627           0.0
# 116     4.732317  -12.876528      7.895422        4.156655           0.0
# 125     4.951970  -12.890778     12.456520        5.515742           0.0
# 134     4.294083  -12.158526      7.352698        2.848361           0.0
# 143     5.180246  -12.791681      9.909380       -0.479226           0.0
# 152     5.333191  -12.710902      2.015577       -2.836322           0.0
# 161     4.840777  -12.699419     17.678198       -8.772728           0.0
# 170     5.343853  -12.165307     11.562576       -5.822232           0.0
# 179     5.211874  -13.223576      3.117104       -2.334934           0.0
# 188     4.120779  -12.182552      8.778375        0.696887           0.0
# 197     4.890877  -12.842099     13.394819       -2.869847           0.0
# 206     4.039438  -12.516291      4.705490       -5.833956           0.0
# 215     5.337901  -13.141964     14.977031        0.867411           0.0
# 224     4.546734  -12.821368      7.701553        5.682250           0.0
# 233     4.961500  -12.623756      9.194117        3.480693           0.0
# 242     4.716005  -12.299425     14.175835       -0.998777           0.0
# 251     4.825422  -12.172092      6.523168       -4.196309           0.0
# 260     5.797226  -11.887686      8.027675        2.087708           0.0
# 269     4.239144  -13.361459      2.250165       -7.013473           0.0
# ...          ...         ...           ...             ...           ...
# 8569    4.955222  -13.612888      5.461308      -16.176962           0.0
# 8576    6.718017  -11.612032     -1.968160       -9.373096           0.0
# 8583    3.582092  -11.338505      9.196531       -7.351637           0.0
# 8591    7.923210  -14.800838      8.034852      -10.614242           0.0
# 8600    1.877367  -12.814734    -18.070448       -3.370961           0.0
# 8609    1.953347  -13.609881      0.603555      -11.102458           0.0
# 8618    2.757931  -10.963537      0.091597       -4.514238           0.0
# 8625    5.362489  -11.126969    -14.453845      -14.834461           0.0
# 8633    4.663021  -12.360432    -11.560560       -7.397805           0.0
# 8644    8.298842  -10.072528    -14.262897      -30.945307           0.0
# 8651    3.351800  -13.625684     -8.667323      -22.237288           0.0
# 8660    9.850875  -13.343844    -15.627778      -26.965236           0.0
# 8667    3.808557  -14.281983     -7.878763       -8.928395           0.0
# 8676    2.360748  -10.243851     13.342926      -12.341137           0.0
# 8687   -1.841602  -13.701757    -19.808660      -13.162257           0.0
# 8699   14.879568  -14.373737    -23.034113      -21.917081           0.0
# 8708    8.443016  -11.595726    -14.025272       -0.400410           0.0
# 8716   -1.117528  -14.538775     -5.009861      -14.469026           0.0
# 8723    4.975927  -11.123019      4.751834      -14.993005           0.0
# 8734    6.931981  -15.304270     42.838257      -20.028214           0.0
# 8745    5.517583  -15.499068    -22.767375      -18.546595           0.0
# 8752    7.429331  -11.196013     -7.392560      -15.548534           0.0
# 8766   12.031855  -15.097590    -27.810188      -24.949753           0.0
# 8774   12.964989  -12.065308    -32.225968      -15.572697           0.0
# 8782    3.967523  -10.333224     16.955437      -21.090668           0.0
# 8790    3.756056  -12.567217    -16.794297      -15.185071           0.0
# 8797    4.141157  -13.354751     -7.894031      -18.971521           0.0
# 8807    4.964479  -10.751059    -19.551206       -4.616912           0.0
# 8814    4.594734  -13.320504     -4.334648      -10.013964           0.0
# 8822    8.716863  -12.577412    -26.554513       -5.341605           0.0
#
#       rotor_speed1  rotor_speed2  rotor_speed3  rotor_speed4      reward
# 8       435.994898    435.986033    437.601868    436.295426  450.984730
# 17      435.994898    435.986033    437.601868    436.295426  450.984693
# 26      435.994898    435.986033    437.601868    436.295426  500.000000
# 35      435.994898    435.986033    437.601868    436.295426  500.000000
# 44      435.994898    435.986033    437.601868    436.295426  450.984767
# 53      435.994898    435.986033    437.601868    436.295426  450.984830
# 62      435.994898    435.986033    437.601868    436.295426  450.984793
# 71      435.994898    435.986033    437.601868    436.295426  450.984611
# 80      435.994898    435.986033    437.601868    436.295426  401.969227
# 89      435.994898    435.986033    437.601868    436.295426  450.984641
# 98      435.994898    435.986033    437.601868    436.295426  450.984600
# 107     435.994898    435.986033    437.601868    436.295426  254.916028
# 116     435.994898    435.986033    437.601868    436.295426  401.969383
# 125     435.994898    435.986033    437.601868    436.295426  401.970271
# 134     435.994898    435.986033    437.601868    436.295426  450.984704
# 143     435.994898    435.986033    437.601868    436.295426  401.969655
# 152     435.994898    435.986033    437.601868    436.295426  401.968274
# 161     435.994898    435.986033    437.601868    436.295426  450.984568
# 170     435.994898    435.986033    437.601868    436.295426  352.953046
# 179     435.994898    435.986033    437.601868    436.295426  401.969609
# 188     435.994898    435.986033    437.601868    436.295426  352.953548
# 197     435.994898    435.986033    437.601868    436.295426  352.955165
# 206     435.994898    435.986033    437.601868    436.295426  500.000000
# 215     435.994898    435.986033    437.601868    436.295426  450.985288
# 224     435.994898    435.986033    437.601868    436.295426  450.984875
# 233     435.994898    435.986033    437.601868    436.295426  450.984730
# 242     435.994898    435.986033    437.601868    436.295426  352.948548
# 251     435.994898    435.986033    437.601868    436.295426  450.984653
# 260     435.994898    435.986033    437.601868    436.295426  254.910308
# 269     435.994898    435.986033    437.601868    436.295426  352.953934
# ...            ...           ...           ...           ...         ...
# 8569    435.994898    435.986033    437.601868    436.295426  401.980385
# 8576    435.994898    435.986033    437.601868    436.295426  107.881154
# 8583    435.994898    435.986033    437.601868    436.295426  156.933299
# 8591    435.994898    435.986033    437.601868    436.295426  450.986384
# 8600    435.994898    435.986033    437.601868    436.295426  254.938305
# 8609    435.994898    435.986033    437.601868    436.295426  254.936602
# 8618    435.994898    435.986033    437.601868    436.295426   58.919120
# 8625    435.994898    435.986033    437.601868    436.295426   58.909488
# 8633    435.994898    435.986033    437.601868    436.295426  450.990935
# 8644    435.994898    435.986033    437.601868    436.295426  156.794149
# 8651    435.994898    435.986033    437.601868    436.295426  303.952368
# 8660    435.994898    435.986033    437.601868    436.295426  156.894992
# 8667    435.994898    435.986033    437.601868    436.295426  500.000000
# 8676    435.994898    435.986033    437.601868    436.295426  401.975055
# 8687    435.994898    435.986033    437.601868    436.295426  254.946540
# 8699    435.994898    435.986033    437.601868    436.295426  500.000000
# 8708    435.994898    435.986033    437.601868    436.295426  205.894446
# 8716    435.994898    435.986033    437.601868    436.295426  450.993439
# 8723    435.994898    435.986033    437.601868    436.295426  205.944502
# 8734    435.994898    435.986033    437.601868    436.295426  450.972075
# 8745    435.994898    435.986033    437.601868    436.295426  156.883983
# 8752    435.994898    435.986033    437.601868    436.295426  107.912728
# 8766    435.994898    435.986033    437.601868    436.295426  156.848280
# 8774    435.994898    435.986033    437.601868    436.295426  205.886368
# 8782    435.994898    435.986033    437.601868    436.295426  156.893908
# 8790    435.994898    435.986033    437.601868    436.295426  352.973297
# 8797    435.994898    435.986033    437.601868    436.295426  107.917287
# 8807    435.994898    435.986033    437.601868    436.295426  156.922447
# 8814    435.994898    435.986033    437.601868    436.295426  254.945251
# 8822    435.994898    435.986033    437.601868    436.295426  205.918856
#
# [1000 rows x 18 columns]

# %%
plt.plot(task3_result['reward'].T, label='reward')
print(task3_result['reward'].describe())
plt.legend()
_ = plt.ylim()
# Out:
# count    8823.000000
# mean       44.902438
# std       108.475912
# min         9.571698
# 25%         9.859832
# 50%         9.881391
# 75%         9.908711
# max       500.000000
# Name: reward, dtype: float64

# %%
## TODO: Train your agent here.
from agents.ddpg_agent import DDPG

final_runtime = 5.                                     # time limit of the episode
final_init_pose = np.array([0., 0., 5., 0., 0., 0.]) # initial pose
final_init_velocities = np.array([5., 5., 5.])         # initial velocities
final_init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
final_file_output = 'ddpg_data.txt'                         # file name for saved results

num_episodes = 100
final_target_pos = np.array([0., 0., 0.])  # teach Quadcopter to land (x=0, y=0, z=0)
task = Task3(final_init_pose, final_init_velocities, final_init_angle_velocities, final_runtime, target_pos=final_target_pos)
agent = DDPG(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4', 'reward']
final_results = {x : [] for x in labels}

with open(final_file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    
    rewards = []
    best_reward = -np.inf
    
    for i_episode in range(1, num_episodes+1):
        state = agent.reset_episode() # start a new episode
        total_reward = 0
        
        while True:
            action = agent.act(state)
            next_state, reward, done = task.step(action)
            agent.step(action, reward, next_state, done)
            state = next_state
            total_reward += reward
            
            to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds) + [total_reward]
            for ii in range(len(labels)):
                final_results[labels[ii]].append(to_write[ii])
            writer.writerow(to_write)
            
            if done:
                if total_reward > best_reward:
                    best_reward = total_reward
                rewards.append(total_reward)
                print("\rEpisode = {:4d}, reward = {:7.3f} (best = {:7.3f})".format(i_episode, total_reward, best_reward), end="")
                break
                      
        sys.stdout.flush()
# Out:
# WARNING:tensorflow:From /Users/rhoesada/anaconda/envs/aind-dl/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:1123: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-bf0a2ae3ae98> in <module>()
#      11 final_target_pos = np.array([0., 0., 0.])  # teach Quadcopter to land (x=0, y=0, z=0)
#      12 task = Task3(final_init_pose, final_init_velocities, final_init_angle_velocities, final_runtime, target_pos=final_target_pos)
# ---> 13 agent = DDPG(task)
#      14 done = False
#      15 labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
#
# /Users/rhoesada/Development/Udacity_MLND_new/projects/quadcopter_rl/agents/ddpg_agent.py in __init__(self, task)
#      15
#      16         # Actor (Policy) Model
# ---> 17         self.actor_local = Actor(self.state_size, self.action_size, self.action_low, self.action_high)
#      18         self.actor_target = Actor(self.state_size, self.action_size, self.action_low, self.action_high)
#      19
#
# /Users/rhoesada/Development/Udacity_MLND_new/projects/quadcopter_rl/agents/actor.py in __init__(self, state_size, action_size, action_low, action_high)
#      23         # Initialize any other variables here
#      24
# ---> 25         self.build_model()
#      26
#      27     def build_model(self):
#
# /Users/rhoesada/Development/Udacity_MLND_new/projects/quadcopter_rl/agents/actor.py in build_model(self)
#      56         # Define optimizer and training function
#      57         optimizer = optimizers.Adam()
# ---> 58         updates_op = optimizer.get_updates(params=self.model.trainable_weights, loss=loss)
#      59         self.train_fn = K.function(
#      60             inputs=[self.model.input, action_gradients, K.learning_phase()],
#
# TypeError: get_updates() missing 1 required positional argument: 'constraints'

# %%
rewards = pd.read_csv("ddpg_data.txt", header=0)
# plt.plot(rewards['x'], label='x')
# plt.plot(rewards['y'], label='y')
plt.plot(rewards['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
plt.plot(rewards['reward'], label='reward')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:
#
# I created 2 different `Tasks` with different reward function:
# 1) `Task0()` to `Task2()` share the same similar reward function with the slight variation in the learning rate
# 2) `Task3()` is the expansion of `Task2()` reward function in which the agent will receive **significant** reward if the agent is able to reach `target_pos`.

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:
#
# 1) I tried two different learning algorithm, which is the `PolicySearch` and `DDPQ`. `DDPG` agent performed **much better** than `PolicySearch` agent.
#
# 2) final choice is `DDPQ` agent with the following hyperparameter:
# - exploration_mu = 0
# - exploration_theta = 0.15
# - exploration_sigma = 0.2
# - buffer_size = 100000
# - batch_size = 64
# - gamma = 0.99 # discount rate
# - tau = 0.01  # for soft update of target parameters
#
# 3) `DDPQ` agents utilizes two neural networks, ie. `Agent` and `Critic` as follows:
# - The `Actor` network uses 3 hidden `Dense` layer with `relu` activation. The output layer uses `sigmoid` activation.
# - The `Critic` network has 2 pathways, ie. `state` and `action`. Each pathway has 2 hidden `Dense` layers. The output layer of this network predicts the `q-value`.

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:
#
# Training the quadcopter to land (where x, y, z=0) is hard. Reducing the learning rate improves the score, however the agent is still not able to obtain significant reward as set in `Task3()`. As shown in the above training using various combination of `PolicySearch` and `DDPQ` agents and several variations in `Task()` hyperparameters settings, the agent shows some improvements. But, it may need much bigger network and training before the agent can really learn to land the quadcopter perfectly.

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
#
# - The hardest part of the project is understanding the starter codes and how the codes relate to Reinforcement Learning framework that we learned in the modules. Also, training the agents can take a long time.
# - The interesting part is able to use different agents and hyperparameters to improve the training. Also, it'll be interesting to try different RL policies and make the neural networks even bigger to get better results.
